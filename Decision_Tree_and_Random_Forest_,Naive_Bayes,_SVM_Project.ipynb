# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahajan2023/DS-projects/blob/Masters/Decision_Tree_and_Random_Forest_%2CNaive_Bayes%2C_SVM_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
dataset=pd.read_csv('/content/Social_Network_Ads.csv')

# %%
dataset
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
dataset.corr()
# Out:
#                   User ID       Age  EstimatedSalary  Purchased
# User ID          1.000000 -0.000721         0.071097   0.007120
# Age             -0.000721  1.000000         0.155238   0.622454
# EstimatedSalary  0.071097  0.155238         1.000000   0.362083
# Purchased        0.007120  0.622454         0.362083   1.000000

# %%
dataset.drop(['User ID','Gender'],inplace= True,axis=1)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Age              400 non-null    int64
#  1   EstimatedSalary  400 non-null    int64
#  2   Purchased        400 non-null    int64
# dtypes: int64(3)
# memory usage: 9.5 KB

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
scaler.fit(dataset.drop('Purchased',axis=1))
# Out:
# StandardScaler()

# %%
scaled_fetures=scaler.transform(dataset.drop('Purchased',axis=1))

# %%
scaled_fetures
# Out:
# array([[-1.78179743, -1.49004624],
#        [-0.25358736, -1.46068138],
#        [-1.11320552, -0.78528968],
#        [-1.01769239, -0.37418169],
#        [-1.78179743,  0.18375059],
#        [-1.01769239, -0.34481683],
#        [-1.01769239,  0.41866944],
#        [-0.54012675,  2.35674998],
#        [-1.20871865, -1.07893824],
#        [-0.25358736, -0.13926283],
#        [-1.11320552,  0.30121002],
#        [-1.11320552, -0.52100597],
#        [-1.6862843 ,  0.47739916],
#        [-0.54012675, -1.51941109],
#        [-1.87731056,  0.35993973],
#        [-0.82666613,  0.30121002],
#        [ 0.89257019, -1.3138571 ],
#        [ 0.70154394, -1.28449224],
#        [ 0.79705706, -1.22576253],
#        [ 0.98808332, -1.19639767],
#        [ 0.70154394, -1.40195167],
#        [ 0.89257019, -0.60910054],
#        [ 0.98808332, -0.84401939],
#        [ 0.70154394, -1.40195167],
#        [ 0.79705706, -1.37258681],
#        [ 0.89257019, -1.46068138],
#        [ 1.08359645, -1.22576253],
# ...

# %%
df=pd.DataFrame(scaled_fetures,columns=['Age','EstimateSalary'])

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(df,dataset['Purchased'],test_size=0.30,random_state=40)

# %%
x_train.shape
# Out:
# (280, 2)

# %%
x_test.shape
# Out:
# (120, 2)

# %%
y_train.shape
# Out:
# (280,)

# %%
y_test.shape
# Out:
# (120,)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
DTC = DecisionTreeClassifier()

# %%
DTC.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred=DTC.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
print(confusion_matrix(y_test,pred))
# Out:
# [[69  8]
#  [ 9 34]]

# %%
correct=69+34

# %%
(correct/120)*100
# Out:
# 85.83333333333333

# %%
# Random Forest

# %% [markdown]
# Random Forest
#     It is a classifiaction algorithm which will take the help from the decision tree on the dataset and will take the average of the outcomes of decision tree to help for improving the accuracy of the prediction.

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(n_estimators=200)

# %%
rfc.fit(x_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=200)

# %%
rfc_pred= rfc.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
print(confusion_matrix(y_test,rfc_pred))
# Out:
# [[73  4]
#  [ 6 37]]

# %%
correct=71+36

# %%
(correct/120)*100
# Out:
# 89.16666666666667

# %%
# Naive Bayes

# %% [markdown]
# Its work on prior proabilty

# %%
from sklearn.naive_bayes import GaussianNB # it follows gaussian type distibution

# %%
GNB = GaussianNB()

# %%
GNB.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred=GNB.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
acc=accuracy_score(y_test,y_pred)

# %%
acc
# Out:
# 0.875

# %%
acc*100
# Out:
# 87.5

# %%
# Support Vectore Mechine lerning Model

# %%
from sklearn.svm import SVC

# %%
classifier=SVC()

# %%
classifier.fit(x_train,y_train)
# Out:
# SVC()

# %%
pred=classifier.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
acc=accuracy_score(y_test,pred)

# %%
acc
# Out:
# 0.9166666666666666

# %%
acc*100
# Out:
# 91.66666666666666
